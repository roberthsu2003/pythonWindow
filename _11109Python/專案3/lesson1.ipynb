# %%
import requests
api_key = "29c4f184354b9889e87f7b494ac86aed"
cityName = "Taipei"
url = f"https://api.openweathermap.org/data/2.5/forecast?q={cityName},tw&APPID={api_key}&lang=zh_tw&units=metric"

response = requests.get(url=url)

if response.ok:
    print("下載成功")
    print(response.text)
else:
    print("下載失敗")
# Out:
# 下載成功
# {"cod":"200","message":0,"cnt":40,"list":[{"dt":1669172400,"main":{"temp":22.36,"feels_like":22.51,"temp_min":22.01,"temp_max":22.36,"pressure":1017,"sea_level":1017,"grnd_level":1016,"humidity":71,"temp_kf":0.35},"weather":[{"id":500,"main":"Rain","description":"小雨","icon":"10d"}],"clouds":{"all":75},"wind":{"speed":3.91,"deg":47,"gust":7.39},"visibility":10000,"pop":0.95,"rain":{"3h":2.47},"sys":{"pod":"d"},"dt_txt":"2022-11-23 03:00:00"},{"dt":1669183200,"main":{"temp":22.08,"feels_like":22.38,"temp_min":21.51,"temp_max":22.08,"pressure":1017,"sea_level":1017,"grnd_level":1014,"humidity":78,"temp_kf":0.57},"weather":[{"id":500,"main":"Rain","description":"小雨","icon":"10d"}],"clouds":{"all":83},"wind":{"speed":4.29,"deg":56,"gust":7.55},"visibility":10000,"pop":0.87,"rain":{"3h":0.96},"sys":{"pod":"d"},"dt_txt":"2022-11-23 06:00:00"},{"dt":1669194000,"main":{"temp":21.39,"feels_like":21.75,"temp_min":20.9,"temp_max":21.39,"pressure":1017,"sea_level":1017,"grnd_level":1015,"humidity":83,"temp_kf":0.49},"weather":[{"id":500,"main":"Rain","description":"小雨","icon":"10d"}],"clouds":{"all":92},"wind":{"speed":4.46,"deg":62,"gust":8.07},"visibility":10000,"pop":0.61,"rain":{"3h":0.58},"sys":{"pod":"d"},"dt_txt":"2022-11-23 09:00:00"},{"dt":1669204800,"main":{"temp":20.81,"feels_like":21.24,"temp_min":20.81,"temp_max":20.81,"pressure":1018,"sea_level":1018,"grnd_level":1017,"humidity":88,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"小雨","icon":"10n"}],"clouds":{"all":100},"wind":{"speed":4.57,"deg":81,"gust":8.28},"visibility":10000,"pop":0.61,"rain":{"3h":0.38},"sys":{"pod":"n"},"dt_txt":"2022-11-23 12:00:00"},{"dt":1669215600,"main":{"temp":20.91,"feels_like":21.38,"temp_min":20.91,"temp_max":20.91,"pressure":1018,"sea_level":1018,"grnd_level":1016,"humidity":89,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"小雨","icon":"10n"}],"clouds":{"all":100},"wind":{"speed":4.19,"deg":79,"gust":7.71},"visibility":10000,"pop":0.45,"rain":{"3h":0.25},"sys":{"pod":"n"},"dt_txt":"2022-11-23 15:00:00"},{"dt":1669226400,"main":{"temp":20.75,"feels_like":21.23,"temp_min":20.75,"temp_max":20.75,"pressure":1016,"sea_level":1016,"grnd_level":1015,"humidity":90,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"小雨","icon":"10n"}],"clouds":{"all":100},"wind":{"speed":3.96,"deg":85,"gust":7.54},"visibility":10000,"pop":0.55,"rain":{"3h":0.33},"sys":{"pod":"n"},"dt_txt":"2022-11-23 18:00:00"},{"dt":1669237200,"main":{"temp":20.67,"feels_like":21.19,"temp_min":20.67,"temp_max":20.67,"pressure":1016,"sea_level":1016,"grnd_level":1014,"humidity":92,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"小雨","icon":"10n"}],"clouds":{"all":100},"wind":{"speed":3.89,"deg":80,"gust":7.33},"visibility":10000,"pop":1,"rain":{"3h":0.55},"sys":{"pod":"n"},"dt_txt":"2022-11-23 21:00:00"},{"dt":1669248000,"main":{"temp":20.8,"feels_like":21.39,"temp_min":20.8,"temp_max":20.8,"pressure":1018,"sea_level":1018,"grnd_level":1016,"humidity":94,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"小雨","icon":"10d"}],"clouds":{"all":100},"wind":{"speed":3.27,"deg":82,"gust":7.22},"visibility":10000,"pop":1,"rain":{"3h":2.83},"sys":{"pod":"d"},"dt_txt":"2022-11-24 00:00:00"},{"dt":1669258800,"main":{"temp":20.71,"feels_like":21.37,"temp_min":20.71,"temp_max":20.71,"pressure":1018,"sea_level":1018,"grnd_level":1016,"humidity":97,"temp_kf":0},"weather":[{"id":501,"main":"Rain","description":"中雨","icon":"10d"}],"clouds":{"all":100},"wind":{"speed":3.3,"deg":75,"gust":5.89},"visibility":4593,"pop":1,"rain":{"3h":7.35},"sys":{"pod":"d"},"dt_txt":"2022-11-24 03:00:00"},{"dt":1669269600,"main":{"temp":20.86,"feels_like":21.48,"temp_min":20.86,"temp_max":20.86,"pressure":1016,"sea_level":1016,"grnd_level":1014,"humidity":95,"temp_kf":0},"weather":[{"id":501,"main":"Rain","description":"中雨","icon":"10d"}],"clouds":{"all":100},"wind":{"speed":3.66,"deg":65,"gust":6.15},"visibility":10000,"pop":1,"rain":{"3h":8.89},"sys":{"po ...

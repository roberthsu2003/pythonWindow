# %%
import requests
url = "https://movies.yahoo.com.tw/movie_thisweek.html"
response = requests.get(url)
if response.status_code == 200:
    print("下載成功")
    print(response.text)
# Out:
# 下載成功
# <!DOCTYPE html>
# <html lang="zh_TW">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1, user-minimum-scale=1, maximum-scale=1">
#   <meta http-equiv="content-type" content="text/html; charset=utf-8">
#   <meta property="fb:app_id" content="501887343352051">
#   <meta property="og:site_name" content="Yahoo奇摩電影戲劇">
#   <link rel="icon" href="/favicon.ico?v=2" />
#
#     <title>本週新片 - Yahoo奇摩電影戲劇</title>
# <meta name="twitter:title" content="本週新片 - Yahoo奇摩電影戲劇">
#   <meta property="og:title" content="本週新片 - Yahoo奇摩電影戲劇">
#
# <link rel="canonical" href="https://movies.yahoo.com.tw/movie_thisweek.html">
# <meta property="og:url" content="https://movies.yahoo.com.tw/movie_thisweek.html">
#
# <meta name="twitter:description" content="Yahoo奇摩電影戲劇提供本週的最新電影資訊，查詢時刻表、看最新預告片，讓你電影資訊不漏接">
# <meta name="description" content="Yahoo奇摩電影戲劇提供本週的最新電影資訊，查詢時刻表、看最新預告片，讓你電影資訊不漏接">
#
#   <meta property="og:description" content="Yahoo奇摩電影戲劇提供本週的最新電影資訊，查詢時刻表、看最新預告片，讓你電影資訊不漏接">
#
# <meta name="twitter:image" content="https://movies.yahoo.com.tw/build/images/ogImage.png?r=1649818392">
# <meta property="og:image" content="https://movies.yahoo.com.tw/build/images/ogImage.png?r=1649818392">
# <meta name="twitter:image:src" content="https://movies.yahoo.com.tw/build/images/ogImage.png?r=1649818392">
# <meta name="keywords" content="電影,院線電影,線上戲劇,線上電影,影劇, yahoo奇摩電影戲劇, 時刻表, 新片, 預告片, 網友滿意榜, yahoo 電影, 劇照, 線上訂票, 票房, 台北票房, 全美票房, 排行榜, 戲院, 片名, 電視, 熱映中, 本週新片, 海報, 滿意度, 期待度">
#
#
#
#
# <script type="application/ld+json">
#   {
#       "@context": "https://schema.org",
#       "@type": "ItemList",
#       "itemListElement": [{"@type":"ListItem","position":1,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E4%BE%8F%E7%BE%85%E7%B4%80%E4%B8%96%E7%95%8C-%E7%B5%B1%E9%9C%B8%E5%A4%A9%E4%B8%8B-jurassic-world-dominion-11809","name":"侏羅紀世界：統霸天下","image":"https://movies.yahoo.com.tw/i/o/production/movies/April2022/3YlWZrhHyJ303TaWbMoE-1080x1711.jpg","director":{"@type":"Person","name":"柯林崔佛洛"},"dateCreated":"2022-06-08","review":{"@type":"Review","reviewRating":{"@type":"Rating","ratingValue":"1.0"},"author":{"@type":"Person","name":"粥"},"reviewBody":"根本就是蝗蟲世界，不刺激，不精彩"},"aggregateRating":{"@type":"AggregateRating","ratingValue":"3.2","bestRating":"5.0","ratingCount":94}}},{"@type":"ListItem","position":2,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E9%9C%B2%E8%8D%89-tsuyukusa-12799","name":"露草","image":"https://movies.yahoo.com.tw/i/o/production/movies/March2022/uammKdP3vxys9UOC0PPC-737x1077.jpg","director":{"@type":"Person","name":"平山秀幸"},"dateCreated":"2022-06-10","aggregateRating":{"@type":"AggregateRating","ratingValue":"4.7","bestRating":"5.0","ratingCount":1}}},{"@type":"ListItem","position":3,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E6%88%91%E7%9A%84%E5%A4%8F%E6%97%A5%E5%A4%A7%E6%88%80%E7%BF%92-one-summer-story-12981","name":"我的夏日大戀習","image":"https://movies.yahoo.com.tw/i/o/production/movies/May2022/m0xCqOM4PtkSZdhf9ILI-1080x1543.jpg","director":{"@type":"Person","name":"沖田修一"},"dateCreated":"2022-06-10","aggregateRating":{"@type":"AggregateRating","ratingValue":"4.7","bestRating":"5.0","ratingCount":1}}},{"@type":"ListItem","position":4,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E9%A4%98%E5%91%BD10%E5%B9%B4-the-last-10-years-13232","name":"餘命10年","image":"https://movies.yahoo.com.tw/i/o/production/movies/May2022/yM1FhvrguPsUg3YhPiF6-1080x1542.jpg","director":{"@type":"Person","name":"藤井道人"},"dateCreated":"2022-06-10","aggregateRating":{"@type":"AggregateRating","ratingValue":"4.8","bestRating":"5.0","ratingCount":2}}},{"@type":"ListItem","position":5,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E9%BB%8E%E5%B7%B4%E5%AB%A9%E7%9A%84%E5%A4%A9%E7%A9%BA-1982-13283","name":"黎巴嫩的天空","image":"https://movies.yahoo.com.tw/i/o/production/movies/May2022/Z8iDlKYWdnHjlhej07Rq-1080x1541.jpg","director":{"@type":"Person","name":"奧亞力穆恩奈斯"},"dateCreated":"2022-06-10"}},{"@type":"ListItem","position":6,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E7%86%9F%E5%A5%B3%E8%A7%A3%E6%94%BE%E4%B8%AD-the-book-of-delights-13363","name":"熟女解放中","image":"https://movies.yahoo.com.tw/i/o/production/movies/May2022/e5kk8HmBvptUQDfgbWda-1080x1543.jpg","director":{"@type":"Person","name":"瑪塞拉羅蒂"},"dateCreated":"2022-06-10"}}]  }
#   </script>
#
#   <link rel="stylesheet" href="/build/css/app.css?id=82564140d26e8a1680ad8763bfcdad1d&amp;r=1649818392">
#   <meta name="oath:guce:consent-host" content="guce.yahoo.com.tw"/>
#
# <!-- Consent Manager Tag : Script -->
# <script type="text/javascript" src="https://consent.cmp.oath.com/cmp.js" async></script>
#
# <!-- Consent Manager Tag : Stubbed (updated 2018-04-27T17:00) -->
# <script type="text/javascript">
#     (function () {
#         var gdprAppliesGlobally = false;
#
#         function addFrame() {
#             if (!window.frames['__cmpLocator']) {
#                 if (document.body && document.body.firstChild) {
#                     var body = document.body,
#                         iframe = document.createElement('iframe');
#
#                       iframe.style.display = 'none';
# 			  iframe.height = iframe.width = 0;
#
#                     iframe.name = '__cmpLocator';
#                     body.insertBefore(iframe, body.firstChild);
#                 } else {
#                     setTimeout(addFrame, 5);
#                 }
#             }
#         }
#
#         addFrame();
#
#         function stubCMP() {
#             var b = arguments;
#             __cmp.a = __cmp.a || [];
#
#             if (!b.length) return __cmp.a;
#             else if (b[0] === 'ping') {
#                 b[2]({
#                     "gdprAppliesGlobally": gdprAppliesGlobally,
#                     "cmpLoaded": false
#                 }, true);
#             }
#             else {
#                 __cmp.a.push([].slice.apply(b));
#             }
#         }
#
#         function cmpMsgHandler(event) {
#             var msgIsString = typeof event.data === "string";
#             var json = event.data;
#             if (msgIsString) {
#                 try {
#                     json = JSON.parse(event.data);
#                 } catch (e) {}
#             }
#             if (json.__cmpCall) {
#                 var i = json.__cmpCall;
#                 window.__cmp(i.command, i.parameter, function (retValue, success) {
#                     var returnMsg = {
#                         "__cmpReturn": {
#                             "returnValue": retValue,
#                             "success": success,
#                             "callId": i.callId
#                         }
#                     };
#                     event.source.postMessage(msgIsString ?
#                         JSON.stringify(returnMsg) : returnMsg, '*');
#                 });
#             }
#         }
#
#         if (typeof (__cmp) !== 'function') {
#             window.__cmp = stubCMP;
#             __cmp.msgHandler = cmpMsgHandler;
#             if (window.addEventListener)
#                 window.addEventListener('message', cmpMsgHandler, false);
#             else window.attachEvent('onmessage', cmpMsgHandler);
#         }
#     })();
#
# </script>
# <!-- End Consent Manager Tag : Stubbed -->
#
#
# <script type="text/javascript">
#     window.__cmp('init');
# </script>
# <script type="text/javascript" src="https://s.yimg.com/nb/AdLib/adlib-prod.umd.min.js"></script></head>
#
# <body id="">
#   <data data-login="false" data-login-href="https://movies.yahoo.com.tw/login"></data>
#   <span id="tracking-data"
#      data-spaceid="794026715"      data-pt="utility"          data-pstcat="本週新片"           ></span>
#   <!--Website-->
#   <div id="maincontainer">
#     <header class="header">
#       <div id="y-header">
#     <nav class="nav content">
#         <ul>
#             <li><a class="gabtn" href="https://tw.yahoo.com/" data-ga="['頻道入口','頻道入口_Yahoo首頁','頁首_頻道入口']"><span class="icon_home"></span>首頁</a></li>
#             <li><a class="gabtn" href="https://tw.mail.yahoo.com/" data-ga="['頻道入口','頻道入口_信箱','頁首_頻道入口']">信箱</a></li>
#             <li><a class="gabtn" href="https://tw.news.yahoo.com/" data-ga="['頻道入口','頻道入口_新聞','頁首_頻道入口']">新聞</a></li>
#             <li><a class="gabtn" href="https://tw.stock.yahoo.com/" data-ga="['頻道入口','頻道入口_股市','頁首_頻道入口']">股市</a></li>
#             <li><a class="gabtn" href="https://tw.news.yahoo.com/weather-forecast/" data-ga="['頻道入口','頻道入口_氣象','頁首_頻道入口']">氣象</a></li>
#             <li><a class="gabtn" href="https://tw.sports.yahoo.com/" data-ga="['頻道入口','頻道入口_運動','頁首_頻道入口']">運動</a></li>
#             <li><a class="gabtn" href="https://tw.news.yahoo.com/entertainment" data-ga="['頻道入口','頻道入口_名人娛樂','頁首_頻道入口']">名人娛樂</a></li>
#             <li><a class="gabtn" href="http://tw.mobile.yahoo.com/" data-ga="['頻道入口','頻道入口_App下載','頁首_頻道入口']">App下載</a></li>
#             <li><a class="gabtn" href="https://tw.buy.yahoo.com/" data-ga="['頻道入口','頻道入口_購物中心','頁首_頻道入口']">購物中心</a></li>
#             <li><a class="gabtn" href="https://tw.mall.yahoo.com/" data-ga="['頻道入口','頻道入口_商域','頁首_頻道入口']">商城</a></li>
#             <li><a class="gabtn" href="https://tw.bid.yahoo.com/" data-ga="['頻道入口','頻道入口_拍賣','頁首_頻道入口']">拍賣</a></li>
#             <li class="nav_more">
#                 <a href="javascript:void(0)">更多<span class="icon_more"></span></a>
#                 <div class="dropdown_list">
#                     <dl>
#                         <dd><a class="gabtn" href="https://tw.video.yahoo.com/" data-ga="['頻道入口','頻道入口_影音','頁首_頻道入口']">影音</a></dd>
#                         <dd><a class="gabtn" href="https://autos.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_汽車機車','頁首_頻道入口']">汽車機車</a></dd>
#                         <dd><a class="gabtn" href="https://movies.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_電影','頁首_頻道入口']">電影</a></dd>
#                         <dd><a class="gabtn" href="https://tw.dictionary.yahoo.com/" data-ga="['頻道入口','頻道入口_字典','頁首_頻道入口']">字典</a></dd>
#                         <dd><a class="gabtn" href="https://games.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_遊戲','頁首_頻道入口']">遊戲</a></dd>
#                         <dd><a class="gabtn" href="https://travel.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_旅遊','頁首_頻道入口']">旅遊</a></dd>
#                         <dd><a class="gabtn" href="https://tw.money.yahoo.com/" data-ga="['頻道入口','頻道入口_理財','頁首_頻道入口']">理財</a></dd>
#                         <dd><a class="gabtn" href="https://house.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_房地產','頁首_頻道入口']">房地產</a></dd>
#                         <dd><a class="gabtn" href="https://style.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_時尚美妝','頁首_頻道入口']">時尚美妝</a></dd>
#                         <dd><a class="gabtn" href="https://tw.discount.yahoo.net/index.php?group=all" data-ga="['頻道入口','頻道入口_折扣城','頁首_頻道入口']">折扣城</a></dd>
#                     </dl>
#                 </div>
#             </li>
#         </ul>
#     </nav>
# </div>
# <div id="kv">
#     <div class="content">
#         <div id="y_hous_serch" class="_c">
#             <div id="y_serch_l">
#                 <a id="ylogo" class="gabtn" href="https://movies.yahoo.com.tw/index.html" data-ga="['電影頻道logo','電影頻道logo_連結','頁首_電影頻道logo']">
#                     <img src="/build/images/header_logo.png?r=1649818392" srcset="/build/images/header_logo@2x.png?r=1649818392 2x, /build/images/header_logo@3x.png?r=1649818392 3x" alt="Yahoo Logo" />
#                 </a>
#                 <form method="get" action="https://tw.search.yahoo.com/search" target="_blank">
#                     <input id="serchinput" name="p" type="text" placeholder="搜尋"  autocomplete="off">
#                     <div class="inputex" style="visibility:hidden"></div>
#
#                     <button class="serch_movie gabtn" data-ga="['top search','top search_電影明星搜尋','']" data-input="['input','serchinput','']">影劇、明星搜尋</button><!--20170531-->
#                     <button class="gabtn" type="submit" data-ga="['top search','top search_網頁搜尋','']" data-input="['input','serchinput','']">網頁搜尋</button><!--20170531-->
#                     <input type="hidden" id="fr" name="fr" value="ush-movies">
#                 </form>
#             </div>
#
#         </div>
#     </div>
# </div>
# <!-- jurisdiction-type: WORLD -->
# <div id="bg_main_menu">
#   <div class="content">
#     <ul id="mainmenu">
#                         <li class="">
#             <a href="https://movies.yahoo.com.tw" target="" class="gabtn" data-ga="['選單','選單_首頁','頁首_選單']">
#               <span>首頁</span>
#             </a>
#           </li>
#                                 <li class=" select ">
#             <a href="https://movies.yahoo.com.tw/movie_thisweek.html" target="" class="gabtn" data-ga="['選單','選單_本週新片','頁首_選單']">
#               <span>本週新片</span>
#             </a>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/movie_intheaters.html" target="" class="gabtn" data-ga="['選單','選單_上映中','頁首_選單']">
#               <span>上映中</span>
#             </a>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/movie_comingsoon.html" target="" class="gabtn" data-ga="['選單','選單_即將上映','頁首_選單']">
#               <span>即將上映</span>
#             </a>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/trailer_index.html" target="" class="gabtn" data-ga="['選單','選單_預告片','頁首_選單']">
#               <span>預告片</span>
#             </a>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/chart.html" target="" class="gabtn" data-ga="['選單','選單_排行榜','頁首_選單']">
#               <span>排行榜</span>
#             </a>
#           </li>
#                                 <li class="hassub ">
#             <a href="https://movies.yahoo.com.tw/article_index.html" class="gabtn" target="" data-ga="['選單','選單_情報站','頁首_選單']">
#               <span>情報站</span>
#             </a>
#             <div class="submenu">
#               <dl class="submenu_inner">
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/movieheadline" target="" class="gabtn" data-ga="['選單','選單_情報站_電影新聞','頁首_選單']">
#                         電影新聞
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/spotlight" target="" class="gabtn" data-ga="['選單','選單_情報站_專題報導','頁首_選單']">
#                         專題報導
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/moviereview" target="" class="gabtn" data-ga="['選單','選單_情報站_影評','頁首_選單']">
#                         影評
#                       </a>
#                   </dt>
#                               </dl>
#             </div>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/tv_index.html" target="" class="gabtn" data-ga="['選單','選單_電視時刻','頁首_選單']">
#               <span>電視時刻</span>
#             </a>
#           </li>
#                                 <li class="hassub ">
#             <a href="https://movies.yahoo.com.tw/ott_index.html" class="gabtn" target="" data-ga="['選單','選單_追劇咖','頁首_選單']">
#               <span>追劇咖</span>
#             </a>
#             <div class="submenu">
#               <dl class="submenu_inner">
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/ottdrama" target="" class="gabtn" data-ga="['選單','選單_追劇咖_線上戲劇','頁首_選單']">
#                         線上戲劇
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/ottmovie" target="" class="gabtn" data-ga="['選單','選單_追劇咖_線上電影','頁首_選單']">
#                         線上電影
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/ott_drama.html" target="" class="gabtn" data-ga="['選單','選單_追劇咖_熱門線上影劇','頁首_選單']">
#                         熱門線上影劇
#                       </a>
#                   </dt>
#                               </dl>
#             </div>
#           </li>
#                   </ul>
#   </div>
# </div>
#     </header>
#     <!--主內容-->
#     <main>
#       <!--top_ad-->
#       <div class="maincontent ">
#                   <div id="boxMAST" class="boxAD">
#             <div id="tgtMAST" class="adpos"></div>
#           </div>
#                 <div id="top_serch" class="content _c">
#           <div data-topserch="0">
#     <div class="tab_serch _c">
#         <div class="tab_hot">
#                             <a href="https://movies.yahoo.com.tw/movieinfo_main/驚奇少女-ms-marvel-12815" target=""
#                    class="gabtn" data-ga="['search box','search box_熱門1','驚奇少女']">驚奇少女</a>
#                             <a href="https://movies.yahoo.com.tw/movieinfo_main/必勝球探-hustle-13383" target=""
#                    class="gabtn" data-ga="['search box','search box_熱門2','必勝球探']">必勝球探</a>
#                             <a href="https://movies.yahoo.com.tw/movieinfo_main/侏羅紀世界-統霸天下-jurassic-world-dominion-11809" target=""
#                    class="gabtn" data-ga="['search box','search box_熱門3','侏羅紀世界']">侏羅紀世界</a>
#                     </div>
#         <a class="btn_booking btn_toptxt gabtn" target="_blank"
#            data-ga="['search box','search box_訂票客服中心','']"
#            href="https://www.ezding.com.tw/page/faq/faq.html">訂票客服中心</a>
#         <a class="btn_all btn_toptxt gabtn" href="https://movies.yahoo.com.tw/theater_list.html"
#            data-ga="['search box','search box_戲院總覽','']">戲院總覽</a>
#         <div class="btn_index_search">
#             <i class="fa fa-file-text-o" aria-hidden="true"></i>
#             <a class="btn_toptxt gabtn" href="https://movies.yahoo.com.tw/category.html"
#            data-ga="['search box','search box_戲院總覽','']">影劇檢索</a>
#         </div>
#     </div>
#
#     <span id="mainURL" data-url="https://movies.yahoo.com.tw"></span>
#     <span id="searchType" data-type="0"></span>
#     <div class="tab_serchbar">
#         <div class="icon_serch"></div>
#         <select name="search_type" id="movie_time">
#             <option value="0">電影時刻</option>
#             <option value="1">電視時刻</option>
#             <option value="2">快速訂票</option>
#             <option value="3">電影/影劇/明星搜尋</option>
#         </select>
#
#         <!--tab_serchbar  style0-->
#         <div class="top_change" data-change = "0" style="">
#             <form id="form_moviearea" method="get" action="https://movies.yahoo.com.tw/movietime_result.html">
#                 <span>選擇<br>片名</span>
#                     <select id="sbox_mid" name="movie_id" class="movie_name" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/in_theater_movies">
#                         <option value="">請選擇片名</option>
#                     </select>
#                 <span>選擇<br>地區</span>
#                 <select id="sbox_aid" name="area_id" class="movie_area">
#
#                 </select>
#                 <div class="btn_serch gabtn"
#                      data-ga="['search box','search box_電影時刻','']" data-input="['select','sbox_mid','sbox_aid']">查詢</div>
#             </form>
#         </div>
#
#         <!--tab_serchbar  style1-->
#         <div class="top_change" data-change = "1" style="display:none;">
#             <form id="form_catechannel" method="get" action="https://movies.yahoo.com.tw/tv_channels.html" style="display:inline;">
#                 <span>選擇<br>分類</span>
#                 <select id="sbox_cid" name="tv_category_id" class="movie_theater">
#                     <option value="">請選擇分類</option>
#                                                                         <option value="1" data-name="西片">西片</option>
#                                                     <option value="2" data-name="國片">國片</option>
#                                                     <option value="3" data-name="戲劇">戲劇</option>
#                                                     <option value="4" data-name="體育">體育</option>
#                                                     <option value="5" data-name="綜合">綜合</option>
#                                                     <option value="6" data-name="知性">知性</option>
#                                                     <option value="7" data-name="日本">日本</option>
#                                                     <option value="8" data-name="音樂">音樂</option>
#                                                     <option value="9" data-name="卡通">卡通</option>
#                                                     <option value="10" data-name="新聞">新聞</option>
#                                                     <option value="11" data-name="財經">財經</option>
#                                                     <option value="12" data-name="宗教">宗教</option>
#                                                             </select>
#                 <span>選擇<br>頻道</span>
#                 <select id="sbox_chid" name="channel" class="movie_name">
#                 </select>
#                 <div class="btn_serch gabtn"
#                      data-ga="['search box','search box_電視時刻','']" data-input="['select','sbox_cid','sbox_chid']">查詢</div>
#             </form>
#             <form id="form_channelname" method="get" action="https://movies.yahoo.com.tw/tvtime_result.html" style="display:inline;">
#                 <input id="sbox_cname" class="tvserch" id="tv_channel_name" name="tv_channel_name" type="text" placeholder="電視節目查詢"  autocomplete="off"
#                        onfocus="this.placeholder=''" onblur="this.placeholder='電視節目查詢'" onkeypress="chlSearchForm(event);">
#                 <div class="btn_serch gabtn" data-ga="['search box','search box_電視節目查詢','']" data-input="['input','sbox_cname','']">查詢</div>
#             </form>
#         </div>
#
#         <!--tab_serchbar  style2-->
#         <div class="top_change" data-change = "2" style="display:none;">
#             <form id="form_movieticket" method="get" action="https://www.ezding.com.tw/page/booking/index.html?channel=yahoo&campaign_code=yahoopc">
#                 <span>選擇<br>戲院</span>
#                 <select id="sbox_tid" name="cinemaId" class="movie_theater" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/cinemas">
#                     <option value="">請選擇戲院</option>
#                 </select>
#                 <span>選擇<br>片名</span>
#                 <select id="sbox_tmid" name="movieId" class="movie_name">
#
#                 </select>
#                 <span>選擇<br>日期</span>
#                 <select name="showDate" class="movie_day">
#
#                 </select>
#                 <span>選擇<br>場次</span>
#                 <select name="session" class="movie_screenings">
#
#                 </select>
#                 <span>選擇<br>數量</span>
#                 <select name="ticketQuantity" class="movie_amount">
#
#                 </select>
#                 <div class="btn_serch gabtn" data-ga="['search box','search box_快速訂票','']"
#                      data-input="['select','sbox_tid','sbox_tmid']">查詢</div>
#             </form>
#         </div>
#
#         <!--tab_serchbar  style3-->
#         <div class="top_change" data-change = "3" style="display:none;">
#             <form id="form_starsearch" method="get" action="https://movies.yahoo.com.tw/moviesearch_result.html">
#                 <select name="movie_type">
#                     <option value="all">全部</option>
#                     <option value="movie">院線電影</option>
#                     <option value="drama">戲劇影集</option>
#                     <option value="online_movie">線上電影</option>
#                 </select>
#                 <input id="starserch" class="starserch" type="text" name="keyword" placeholder="電影 / 明星搜尋"
#                        onfocus="this.placeholder=''" onblur="this.placeholder='電影/ 明星搜尋'" autocomplete="off">
#                 <div class="inputex" style="visibility:hidden">
#                 </div>
#                 <div class="btn_serch gabtn" data-ga="['search box','search box_電影明星搜尋','']"
#                      data-input="['input','starserch','']">查詢</div>
#             </form>
#         </div>
#
#     </div>
# </div>
#         </div>
#                 <div id="container" class="content _c">
#           <div id="content_r">
#             <!--AD 300X250-->
# <div id="boxLREC" class="ad_300_250 r_box" data-ad="LREC" data-ad-hashtag="">
#   <div id="tgtLREC" class="adpos"></div>
# </div>
# <!--AD 300X100-->
# <div id="boxNP1" class="ad_300_100 r_box" data-ad="NP1">
#   <div id="tgtNP1" class="adpos"></div>
# </div>
# <!--電影排行榜-->
# <div class="r_box _c">
#   <div class="title">
#         <span>
#             電影排行榜
#         </span>
#   </div>
#
#   <div class="r_box_inner">
#     <ul class="tabbox_btn_r">
#       <li data-id="list1" class="select">台北票房榜</li>
#       <li data-id="list2" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/movie_rank_tab" data-type="us">全美票房榜</li>
#       <li data-id="list3" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/movie_rank_tab" data-type="popular">預告片榜</li>
#     </ul>
#     <div class="ranking_inner_r">
#       <div class="tab-content">
#         <div id="list1" class="tab-pane">
#           <div class="ranking_top_info_r _c">
#             <div class="ranking_top_info_img_r">
#             <a
#                 class="gabtn"
#                 href="https://movies.yahoo.com.tw/movieinfo_main/%E6%8D%8D%E8%A1%9B%E6%88%B0%E5%A3%AB-%E7%8D%A8%E8%A1%8C%E4%BF%A0-top-gun-maverick-10159"
#                 data-ga="['電影排行榜','電影排行榜_台北票房榜','捍衛戰士：獨行俠']"
#             >
#                 <img src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/March2022/IPaDhsb4uOa5QvdXGh3G-1080x1601.jpg" alt="">
#             </a>
#         </div>
#         <div class="ranking_top_info_inner_r">
#             <a
#                 class="gabtn"
#                 href="https://movies.yahoo.com.tw/movieinfo_main/%E6%8D%8D%E8%A1%9B%E6%88%B0%E5%A3%AB-%E7%8D%A8%E8%A1%8C%E4%BF%A0-top-gun-maverick-10159"
#                 data-ga="['電影排行榜','電影排行榜_台北票房榜','捍衛戰士：獨行俠']"
#             >
#                 捍衛戰士：獨行俠
#             </a>
#             <span class="text_truncate_4 text_truncate_dot">派拉蒙影業1986年推出的《捍衛戰士》，由湯姆克魯斯主演，是一齣以航空母艦與美國海軍戰鬥機武器學校為背景的勵志動作電影，在當年締造了全球3億5千6百多萬美元的票房成績。睽違33年之後，派拉蒙影業將在2020年6月26日暑假檔期推出美國軍事動作鉅片《捍衛戰士：獨行俠》，是1986年電影《捍衛戰士》的續集，同樣選擇在美國�
span>
#                     </li>
#                 </a>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/PINA-2012-pina-4270"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','PINA(2012)']"
#                 >
#                     <li class="">
#                         <div class="num">9</div>
#                         <span>PINA(2012)</span>
#                     </li>
#                 </a>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A4%B1%E9%80%9F%E6%AF%8D%E8%A6%AA-full-time-13262"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','失速母親']"
#                 >
#                     <li class="">
#                         <div class="num">10</div>
#                         <span>失速母親</span>
#                     </li>
#                 </a>
#                         </ul>
#
# <div class="rankin_time_r">統計時間 : 2022-06-04~2022-06-05</div>
#         </div>
#         <div id="list2" class="tab-pane"></div>
#         <div id="list3" class="tab-pane"></div>
#       </div>
#       <div class="btn_plus_more gabtn rk"  data-ga="['電影排行榜','電影排行榜_台北票房榜_看更多','']">
#         <a href="https://movies.yahoo.com.tw/chart.html">
#           <div class="plus"></div>看更多
#         </a>
#       </div>
#       <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_全美票房榜_看更多','']">
#         <a href="https://movies.yahoo.com.tw/chart.html?cate=us">
#           <div class="plus"></div>看更多
#         </a>
#       </div>
#       <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_預告片榜_看更多','']">
#         <a href="https://movies.yahoo.com.tw/chart.html?cate=trailer">
#           <div class="plus"></div>看更多
#         </a>
#       </div>
#     </div>
#   </div>
# </div>
# <!--AD 300X156-->
# <div class="native-ad-right">
# </div>
# <!--AD 300X250-->
# <div id="boxLREC3" class="ad_300_250 r_box" data-ad="LREC3">
#   <div id="tgtLREC3" class="adpos"></div>
# </div>
#
#   <!--FB-->
# <div class="fb r_box">
# </div>
#
# <!--你最近瀏覽的電影-->
# <div class="r_box _c">
#   <div class="title">
#         <span>
#             你最近瀏覽的電影
#         </span>
#   </div>
#   <div class="r_box_inner">
#           <ul class="recently_viewed">
#               </ul>
#       </div>
# </div>
#
# <div></div>
#           </div>
#           <div id="content_l">
#               <div class="title ">
#     <h1>
#         本週新片
#     </h1>
#   </div>
#
#     <div class="release_box">
#     <ul class="filter-nav">
#                         <li><a href="https://movies.yahoo.com.tw/movie_thisweek.html" class="picked">院線電影</a></li>
#                                 <li><a href="https://movies.yahoo.com.tw/drama_thisweek.html">戲劇影集</a></li>
#                                 <li><a href="https://movies.yahoo.com.tw/onlinemovie_thisweek.html">線上電影</a></li>
#             </ul>
#         <ul class="release_list">
#               <li>
#           <div class="release_foto">
#             <a href="https://movies.yahoo.com.tw/movieinfo_main/%E4%BE%8F%E7%BE%85%E7%B4%80%E4%B8%96%E7%95%8C-%E7%B5%B1%E9%9C%B8%E5%A4%A9%E4%B8%8B-jurassic-world-dominion-11809"
#                class="gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','侏羅紀世界：統霸天下']">
#                <div class="type_label movie">院線電影</div>
#               <img class="lazy-load" data-src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/April2022/3YlWZrhHyJ303TaWbMoE-1080x1711.jpg" alt="">
#             </a>
#           </div>
#           <div class="release_info">
#             <div class="release_info_text">
#               <div class="release_movie_name">
#                 <a href="https://movies.yahoo.com.tw/movieinfo_main/%E4%BE%8F%E7%BE%85%E7%B4%80%E4%B8%96%E7%95%8C-%E7%B5%B1%E9%9C%B8%E5%A4%A9%E4%B8%8B-jurassic-world-dominion-11809"
#                    class="gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','侏羅紀世界：統霸天下']">
#                   侏羅紀世界：統霸天下</a>
#                 <div class="en">
#                   <a href="https://movies.yahoo.com.tw/movieinfo_main/%E4%BE%8F%E7%BE%85%E7%B4%80%E4%B8%96%E7%95%8C-%E7%B5%B1%E9%9C%B8%E5%A4%A9%E4%B8%8B-jurassic-world-dominion-11809"
#                      class="gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','侏羅紀世界：統霸天下']">
#                     Jurassic World Dominion</a>
#                 </div>
#                 <dl class="levelbox">
#                                     <dt>
#                   <div class="level_name">期待度</div>
#                   <div class="leveltext">
#                     <span>98%</span>
#                     網友想看
#                   </div>
#                   </dt>
#                                                       <dd>
#                     <div class="level_name">滿意度</div>
#                     <div class="leveltext">
#                       <span class="count" data-run="0" data-num="3.2">0</span>
#                       綜合評分
#                     </div>
#                   </dd>
#                                   </dl>
#               </div>
#
#               <div class="release_drama_season">
#                               </div>
#               <div class="release_movie_time">
#                 <span>上映日期：</span>
#                 2022-06-08
#               </div>
#               <div class="release_text">
#                 <span class="jq_text_overflow_180 jq_text_overflow_href_list" data-url="https://movies.yahoo.com.tw/movieinfo_main/%E4%BE%8F%E7%BE%85%E7%B4%80%E4%B8%96%E7%95%8C-%E7%B5%B1%E9%9C%B8%E5%A4%A9%E4%B8%8B-jurassic-world-dominion-11809">
#                   今年夏天，準備體驗兩個世代的演員，首度同台演出《侏羅紀公園》電影系列史詩般的最終篇章。元老級演員蘿拉鄧恩、傑夫高布倫以及山姆尼爾，加入克里斯普瑞特與布萊絲達拉斯霍華，共同主演《侏羅紀世界：統霸天下》，這是一部故事場景橫越全球、既大膽又創意又令人看得喘不過氣來的全新冒險動作強檔鉅片。<br />
# <br />
# 《侏羅紀世界：統霸天下》一片是《侏羅紀世界》電影系列統籌及導演柯林崔佛洛的全新力作，故事發生在努布拉島完全毀滅的四年之後。恐龍現在和全世界的人類共同生存，同時也在獵捕食物。這個微妙的平衡即將重新塑造未來，並且即將決定人類從此以後，是否能夠與史上最可怕的生物共同生存，同時卻仍然保持地球頂級掠食者的地位。<br />
# <br />
# 環球影業暨安培林娛樂出品的《侏羅紀世界：統霸天下》一片，將這個總票房超過50億美元的電影系列推向大膽與未知的領域，片中有前所未見的恐龍、驚險刺激的動作場面，以及令人瞠目結舌的全新視覺特效。<br />
# <br />
%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-162952129.html?movie_id=13283"
#                    class="btn_s_vedio gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','黎巴嫩的天空']">
#                   預告片
#                 </a>
#                                             <a href="https://movies.yahoo.com.tw/movieinfo_photos.html/id=13283" class="btn_s_foto">劇照</a>
#                                                               <a href="https://movies.yahoo.com.tw/movietime_result.html/id=13283"
#                     class="btn_s_time gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','黎巴嫩的天空']">
#                     時刻表
#                   </a>
#                                           </div>
#           </div>
#         </li>
#               <li>
#           <div class="release_foto">
#             <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%86%9F%E5%A5%B3%E8%A7%A3%E6%94%BE%E4%B8%AD-the-book-of-delights-13363"
#                class="gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','熟女解放中']">
#                <div class="type_label movie">院線電影</div>
#               <img class="lazy-load" data-src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/May2022/e5kk8HmBvptUQDfgbWda-1080x1543.jpg" alt="">
#             </a>
#           </div>
#           <div class="release_info">
#             <div class="release_info_text">
#               <div class="release_movie_name">
#                 <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%86%9F%E5%A5%B3%E8%A7%A3%E6%94%BE%E4%B8%AD-the-book-of-delights-13363"
#                    class="gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','熟女解放中']">
#                   熟女解放中</a>
#                 <div class="en">
#                   <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%86%9F%E5%A5%B3%E8%A7%A3%E6%94%BE%E4%B8%AD-the-book-of-delights-13363"
#                      class="gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','熟女解放中']">
#                     The Book of Delights</a>
#                 </div>
#                 <dl class="levelbox">
#                                     <dt>
#                   <div class="level_name">期待度</div>
#                   <div class="leveltext">
#                     <span>100%</span>
#                     網友想看
#                   </div>
#                   </dt>
#                                                     </dl>
#               </div>
#
#               <div class="release_drama_season">
#                               </div>
#               <div class="release_movie_time">
#                 <span>上映日期：</span>
#                 2022-06-10
#               </div>
#               <div class="release_text">
#                 <span class="jq_text_overflow_180 jq_text_overflow_href_list" data-url="https://movies.yahoo.com.tw/movieinfo_main/%E7%86%9F%E5%A5%B3%E8%A7%A3%E6%94%BE%E4%B8%AD-the-book-of-delights-13363">
#                   ★ 布宜諾斯艾利斯國際獨立電影節最佳女主角得主<br />
# ★巴西影后 席夢妮史波拉多爾 一絲不掛 全裸上陣<br />
# ★女文豪 克拉麗斯利斯佩克托 探索自我 求真之作<br />
# ★聖保羅國際電影節<br />
# <br />
# 「你曾經毫無保留的交出自己的身體嗎?」<br />
# 羅莉是個孤獨且憂鬱的女人，她把工作與私生活切分得很好，工作上她是一個小學老師，私人感情上她嚮往速食沒有負擔的床伴關係。偶然機會，她認識一個頗負盛名的哲學教授尤利西斯，自我中心，老愛把人激怒。即使他對女人一籌莫展，即使羅莉不想要束縛，但她還是從他身上學習愛人的勇氣，從中更認識自己：正視自我的情緒，獲得身心靈一體的滋潤。
#                 </span>
#               </div>
#
#
#             </div>
#             <div class="release_btn color_btnbox">
#               <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%86%9F%E5%A5%B3%E8%A7%A3%E6%94%BE%E4%B8%AD-the-book-of-delights-13363" class="btn_s_introduction"
#                  class="gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','熟女解放中']">
#                                      <span>電影資訊</span>
#                               </a>
#                                             <a href="https://movies.yahoo.com.tw/video/%E7%86%9F%E5%A5%B3%E8%A7%A3%E6%94%BE%E4%B8%AD-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-145519335.html?movie_id=13363"
#                    class="btn_s_vedio gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','熟女解放中']">
#                   預告片
#                 </a>
#                                             <a href="https://movies.yahoo.com.tw/movieinfo_photos.html/id=13363" class="btn_s_foto">劇照</a>
#                                                               <a href="https://movies.yahoo.com.tw/movietime_result.html/id=13363"
#                     class="btn_s_time gabtn" data-ga="['本週新片','本週新片_本週新片第1頁','熟女解放中']">
#                     時刻表
#                   </a>
#                                           </div>
#           </div>
#         </li>
#           </ul>
#   </div>
#
#           </div>
#         </div>
#       </div>
#     </main>
#     <footer id="footer" class="clearfix" style="display: block;">
#       <div id="loadbox">
#   <a class="gabtn" href="https://tw.help.yahoo.com/kb/helpcentral" target="_blank"
#      data-ga="['其他連結','其他連結_服務中心','頁尾_其他連結']">服務中心</a> | <a class="gabtn"
#                                                             href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/index.htm"
#                                                             target="_blank"
#                                                             data-ga="['其他連結','其他連結_隱私權','頁尾_其他連結']">隱私權(更新)</a> | <a
#     class="gabtn" href="https://yahoo.uservoice.com/forums/600523" target="_blank"
#     data-ga="['其他連結','其他連結_建議','頁尾_其他連結']">建議</a> | <a class="gabtn"
#                                                        href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/adinfo/"
#                                                        target="_blank" data-ga="['其他連結','其他連結_關於我們的廣告','頁尾_其他連結']">關於我們的廣告</a>
#   | <a class="gabtn" href="https://info.yahoo.com/legal/tw/yahoo/utos/zh-hant-tw/" target="_blank"
#        data-ga="['其他連結','其他連結_服務條款','頁尾_其他連結']">服務條款(更新)</a>
#   | <a href="" target="_blank">
#
#           </a>
#   由Yahoo奇摩電影戲劇 提供
# </div>    </footer>
#   </div>
#
# <!-- Javascript -->
# <script src="https://s.yimg.com/ss/rapid3.js"></script>
# <script src="https://s.yimg.com/ss/rapidworker-1.2.js"></script>
#
# <!-- Native Ad -->
# <script type="text/javascript">
#   const nativeAdAll = "bdd2eb9c-51e8-404a-921c-ae7090fc5fda";
#   const nativeAdOption = "";
#
#   window.native = window.native || [];
#   window.native.push(nativeAdAll);
#   if(nativeAdOption.length) {
#     window.native.push(nativeAdOption);
#   }
#   window.apiKey = "QS4CB5BPWQKCYKVVSR89";
#
#   (function(d) {
#     var script = d.createElement("script");
#     script.async = true;
#     script.src = "https://s.yimg.com/dy/ads/native.js";
#     d.body.appendChild(script);
#   })(document);
# </script>
#
#
# <script type="text/javascript" src="/build/js/app.js?id=f686f3bbd72ba3b5e998b8f9bfe5e2c2&amp;r=1649818392"></script>
# <script>
#     var DARLA_CONFIG = {
#         "positions": {
#             "LREC" : {
#                 id: "LREC",
#                 name: "LREC",
#                 clean: "boxLREC",
#                 dest: "tgtLREC",
#                 w: 300,
#                 h: 250,
#                 //async: true,
#                 metaSize: true
#             },
#             "LREC3" : {
#                 id: "LREC3",
#                 name: "LREC3",
#                 clean: "boxLREC3",
#                 dest: "tgtLREC3",
#                 w: 300,
#                 h: 250,
#                 //async: true,
#                 metaSize: true
#             },
#             "LDRB" : {
#                 id: "LDRB",
#                 name: "LDRB",
#                 clean: "boxLDRB",
#                 dest: "tgtLDRB",
#                 w: 728,
#                 h: 90,
#                 //async: true,
#                 metaSize: true
#             },
#             "NP1" : {
#                 id: "NP1",
#                 name: "NP1",
#                 clean: "boxNP1",
#                 dest: "tgtNP1",
#                 w: 300,
#                 h: 100,
#                 //async: true,
#                 metaSize: true
#             },
#             //original config
#             // "MAST" : {
#             //     id: "MAST",
#             //     name: "MAST",
#             //     clean: "boxMAST",
#             //     dest: "tgtMAST",
#             //     w: 970,
#             //     h: 250,
#             //     async: true,
#             //     metaSize: true
#             // },
#             //from sports fp
#             "MAST":{
#                 id:"MAST",
#                 name:"MAST", //add
#                 w:970,
#                 h:250,
#                 //async:true, //add
#                 autoFetch:false,
#                 fr:"expIfr_exp",
#                 supports:{
#                     "exp-ovr":1,
#                     "exp-push":1,
#                     "resize-to":1
#                 },
#                 enable:true,
#                 staticLayou:false,
#                 fdb:false,
#                 closeBtn:{
#                     "mode":2,
#                     "useShow":1,
#                     "adc":0
#                 },
#                 metaSize:true,
#                 clean:"boxMAST",
#                 dest:"tgtMAST",
#                 fallback:null,
#                 failed:false
#             },
# 	    	"DEFAULT": {
# 		    	supports: {
# 			    	"bg": 1,
# 				    "exp-ovr": 1,
# 				    "exp-push": 0,
# 				    "lyr": 0,
# 				    "cmsg":1
# 			    }
# 		    }
#         }, events: {
# 		        reloadLREC: {
# 		            ps: 'LREC',
# 		            sp: '794026715'
# 		        },
# 		        reloadNP1: {
# 		            ps: 'NP1',
# 		            sp: '794026715'
# 		        },
# 		        reloadLREC3: {
# 		            ps: 'LREC3',
# 		            sp: '794026715'
# 		        },
# 		    }
#     };
#  </script>
#  <script src="https://fc.yahoo.com/sdarla/php/client.php?f=794026715&debug=1&l=MAST{dest:tgtMAST,azn:970x250},LREC{dest:tgtLREC,azn:300x250},LREC3{dest:tgtLREC3,azn:300x250},NP1{dest:tgtNP1,azn:300x100},LDRB{dest:tgtLDRB,azn:728x90}&amp;npv=1&amp;"></script>
#
# <noscript><img src="https://sb.scorecardresearch.com/p?c1=2&c2=7241469&c7=https%3A%2F%2Fmovies.yahoo.com.tw%2Fmovie_thisweek.html&c5=794026715&cv=2.0&cj=1" width="1" height="1" alt=""/></noscript>
# <script>
#
#
#
#   </script>
#
#
# </body>
#
# </html>

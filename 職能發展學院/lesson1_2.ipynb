# %%
import requests
url = "https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"
response = requests.get(url)
dataList = response.json()
print(dataList.__class__)
# Out:
# <class 'list'>

# %%
dataList
# Out:
# [{'sno': '500101001',
#   'sna': 'YouBike2.0_捷運科技大樓站',
#   'tot': 28,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.02605,
#   'lng': 121.5436,
#   'ar': '復興南路二段235號前',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Technology Bldg. Sta.',
#   'aren': 'No.235， Sec. 2， Fuxing S. Rd.',
#   'bemp': 27,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101002',
#   'sna': 'YouBike2.0_復興南路二段273號前',
#   'tot': 15,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.02565,
#   'lng': 121.54357,
#   'ar': '復興南路二段273號西側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.',
#   'aren': 'No.273， Sec. 2， Fuxing S. Rd. (West)',
#   'bemp': 13,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101003',
#   'sna': 'YouBike2.0_國北教大實小東側門',
#   'tot': 16,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:46:13',
#   'lat': 25.02429,
#   'lng': 121.54124,
#   'ar': '和平東路二段96巷7號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTUE Experiment Elementary School (East)',
#   'aren': 'No. 7， Ln. 96， Sec. 2， Heping E. Rd',
#   'bemp': 14,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:46:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101004',
#   'sna': 'YouBike2.0_和平公園東側',
#   'tot': 11,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:28:03',
#   'lat': 25.02351,
#   'lng': 121.54282,
#   'ar': '和平東路二段118巷33號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Heping Park (East)',
#   'aren': 'No. 33， Ln. 118， Sec. 2， Heping E. Rd',
#   'bemp': 11,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:28:03',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101005',
#   'sna': 'YouBike2.0_辛亥復興路口西北側',
#   'tot': 16,
#   'sbi': 2,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.02153,
#   'lng': 121.54299,
#   'ar': '復興南路二段368號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Xinhai Fuxing Rd. Intersection (Northwest)',
#   'aren': 'No. 368， Sec. 2， Fuxing S. Rd.',
#   'bemp': 14,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101006',
#   'sna': 'YouBike2.0_復興南路二段280號前',
#   'tot': 11,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:42:04',
#   'lat': 25.02429,
#   'lng': 121.54328,
#   'ar': '復興南路二段280號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No. 280， Sec. 2， Fuxing S. Rd.',
#   'aren': 'No. 280， Sec. 2， Fuxing S. Rd.',
#   'bemp': 10,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:42:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101007',
#   'sna': 'YouBike2.0_復興南路二段340巷口',
#   'tot': 11,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:21:22',
#   'lat': 25.02253,
#   'lng': 121.54326,
#   'ar': '復興南路二段342號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Ln. 340， Sec. 2， Fuxing S. Rd.',
#   'aren': 'No. 342， Sec. 2， Fuxing S. Rd.',
#   'bemp': 10,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:21:22',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101008',
#   'sna': 'YouBike2.0_新生南路三段52號前',
#   'tot': 17,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:45:20',
#   'lat': 25.02112,
#   'lng': 121.53407,
#   'ar': '新生南路三段52號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No. 52， Sec. 3， Xinsheng S. Rd.',
#   'aren': 'No. 52， Sec. 3， Xinsheng S. Rd.',
#   'bemp': 16,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:45:20',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101009',
#   'sna': 'YouBike2.0_新生南路三段66號前',
#   'tot': 16,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:32:04',
#   'lat': 25.01976,
#   'lng': 121.53384,
#   'ar': '新生南路三段66號東側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No. 66， Sec. 3， Xinsheng S. Rd.',
#   'aren': 'No. 66， Sec. 3， Xinsheng S. Rd. (East)',
#   'bemp': 16,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:32:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101010',
#   'sna': 'YouBike2.0_新生南路三段82號前',
#   'tot': 20,
#   'sbi': 2,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.01894,
#   'lng': 121.53361,
#   'ar': '新生南路三段82號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No. 82， Sec. 3， Xinsheng S. Rd.',
#   'aren': 'No. 82， Sec. 3， Xinsheng S. Rd.',
#   'bemp': 18,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101011',
#   'sna': 'YouBike2.0_羅斯福路三段333巷9號旁',
#   'tot': 7,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2021-12-11 09:31:03',
#   'lat': 25.01757,
#   'lng': 121.53271,
#   'ar': '羅斯福路三段333巷9號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No. 9， Ln. 333， Sec. 3， Roosevelt Rd.',
#   'aren': 'No. 9， Ln. 333， Sec. 3， Roosevelt Rd.',
#   'bemp': 7,
#   'act': '0',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2021-12-11 09:31:03',
#   'infoDate': '2021-12-11'},
#  {'sno': '500101012',
#   'sna': 'YouBike2.0_辛亥路一段30號前',
#   'tot': 8,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:08:04',
#   'lat': 25.01986,
#   'lng': 121.52982,
#   'ar': '辛亥路一段30號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No. 30， Sec. 1， Xinhai Rd.',
#   'aren': 'No. 30， Sec. 1， Xinhai Rd.',
#   'bemp': 8,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:08:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101013',
#   'sna': 'YouBike2.0_和平復興路口西北側',
#   'tot': 9,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:50:23',
#   'lat': 25.02543,
#   'lng': 121.54332,
#   'ar': '復興南路二段236號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Heping Fuxing Rd. Intersection (Northwest)',
#   'aren': 'No. 236， Sec. 2， Fuxing S. Rd.',
#   'bemp': 9,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:23',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101014',
#   'sna': 'YouBike2.0_羅斯福路三段311號前',
#   'tot': 11,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:47:12',
#   'lat': 25.01717,
#   'lng': 121.53202,
#   'ar': '羅斯福路三段311號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No. 311， Sec. 3， Roosevelt Rd.',
#   'aren': 'No. 311， Sec. 3， Roosevelt Rd.',
#   'bemp': 10,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:47:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101015',
#   'sna': 'YouBike2.0_大安運動中心停車場',
#   'tot': 14,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:47:04',
#   'lat': 25.020348,
#   'lng': 121.546446,
#   'ar': '敦南街76巷28號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Taipei Da-an Sports Center Parking lot',
#   'aren': 'No. 28， Ln. 76， Dunnan St.',
#   'bemp': 13,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:47:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101016',
#   'sna': 'YouBike2.0_羅斯福路三段245號前',
#   'tot': 8,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.01927,
#   'lng': 121.52989,
#   'ar': '羅斯福路三段245號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No. 245， Sec. 3， Roosevelt Rd.',
#   'aren': 'No. 245， Sec. 3， Roosevelt Rd.',
#   'bemp': 8,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101017',
#   'sna': 'YouBike2.0_羅斯福路三段269巷5號前',
#   'tot': 10,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-01-19 09:31:03',
#   'lat': 25.01913,
#   'lng': 121.53079,
#   'ar': '羅斯福路三段269巷5號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_No. 5， Ln. 269， Sec. 3， Roosevelt Rd.',
#   'aren': 'No. 5， Ln. 269， Sec. 3， Roosevelt Rd.',
#   'bemp': 10,
#   'act': '0',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-01-19 09:31:03',
#   'infoDate': '2022-01-19'},
#  {'sno': '500101018',
#   'sna': 'YouBike2.0_溫州公園',
#   'tot': 5,
#   'sbi': 2,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.01895,
#   'lng': 121.53156,
#   'ar': '羅斯福路三段283巷11號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Wenzhou Park',
#   'aren': 'No. 11， Ln. 283， Sec. 3， Roosevelt Rd.',
#   'bemp': 3,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101019',
#   'sna': 'YouBike2.0_和平臥龍街口',
#   'tot': 15,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:04',
#   'lat': 25.024461,
#   'lng': 121.546705,
#   'ar': '臥龍街1號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Heping Wolong St. Intersection',
#   'aren': 'No. 1， Wolong St.',
#   'bemp': 15,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101020',
#   'sna': 'YouBike2.0_溫州停車場',
#   'tot': 5,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:45:28',
#   'lat': 25.02093,
#   'lng': 121.5331,
#   'ar': '新生南路三段54巷/溫州街口',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Wenzhou Parking Lot',
#   'aren': 'Ln. 54， Sec. 3， Xinsheng S. Rd. & Wenzhou St. Intersection',
#   'bemp': 4,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:45:28',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101021',
#   'sna': 'YouBike2.0_銘傳國小側門',
#   'tot': 7,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:45:28',
#   'lat': 25.01385,
#   'lng': 121.53549,
#   'ar': '羅斯福路四段21號旁天橋下',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Taipei Municipal MingChuan Elementary School(Side Gate)',
#   'aren': 'No. 21， Sec. 4， Roosevelt Rd.',
#   'bemp': 6,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:45:28',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101022',
#   'sna': 'YouBike2.0_捷運公館站(2號出口)',
#   'tot': 60,
#   'sbi': 10,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.01491,
#   'lng': 121.53438,
#   'ar': '捷運公館站(2號出口)外側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Gongguan Sta. (Exit 2)',
#   'aren': 'MRT Gongguan Sta. (Exit 2)',
#   'bemp': 50,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101023',
#   'sna': 'YouBike2.0_第二學生活動中心',
#   'tot': 27,
#   'sbi': 11,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:50:31',
#   'lat': 25.01244,
#   'lng': 121.53661,
#   'ar': '羅斯福路四段107號(西南側)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_2nd Student Activity Center',
#   'aren': 'No. 107， Sec. 4， Roosevelt Rd.(Southwest)',
#   'bemp': 16,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:31',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101024',
#   'sna': 'YouBike2.0_臺灣科技大學正門',
#   'tot': 30,
#   'sbi': 11,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:46:13',
#   'lat': 25.01451,
#   'lng': 121.54142,
#   'ar': '基隆路四段43號(臺灣科技大學正門旁小側門靠田徑場)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTUST(Main Gate)',
#   'aren': 'No. 43， Sec. 4， Keelung Rd.',
#   'bemp': 19,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:46:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101025',
#   'sna': 'YouBike2.0_臺灣科技大學側門',
#   'tot': 35,
#   'sbi': 18,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.01295,
#   'lng': 121.53973,
#   'ar': '基隆路四段73巷與基隆路口',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTUST(Side Gate)',
#   'aren': 'Ln. 73， Sec. 4， Keelung Rd. Intersection',
#   'bemp': 16,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101026',
#   'sna': 'YouBike2.0_公館公園',
#   'tot': 15,
#   'sbi': 4,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:47:12',
#   'lat': 25.01137,
#   'lng': 121.54062,
#   'ar': '羅斯福路四段113巷基隆路四段41巷口',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Gongguan Park',
#   'aren': 'Ln. 113， Sec. 4， Roosevelt Rd. & Ln. 41， Sec. 4， Keelung Rd. Intersection',
#   'bemp': 11,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:47:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101027',
#   'sna': 'YouBike2.0_臺灣科技大學後門',
#   'tot': 39,
#   'sbi': 7,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.01182,
#   'lng': 121.54165,
#   'ar': '基隆路四段41巷68弄臺科帆船大樓旁',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTUST(Back Gate)',
#   'aren': 'Aly. 68， Ln. 41， Sec. 4， Keelung Rd.',
#   'bemp': 32,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101028',
#   'sna': 'YouBike2.0_臺大醫學院附設癌醫中心',
#   'tot': 20,
#   'sbi': 9,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:40:27',
#   'lat': 25.01426,
#   'lng': 121.54382,
#   'ar': '基隆路三段155巷57號西側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU Cancer Center',
#   'aren': 'No. 57， Ln. 155， Sec. 3， Keelung Rd.(West)',
#   'bemp': 11,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:40:27',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101029',
#   'sna': 'YouBike2.0_臺大環研大樓',
#   'tot': 15,
#   'sbi': 10,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:40:27',
#   'lat': 25.01234,
#   'lng': 121.54503,
#   'ar': '芳蘭路/基隆路三段155巷口',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU Environment Research Building',
#   'aren': 'Fanglan Rd & Ln. 155， Sec. 3， Keelung Rd. Intersection',
#   'bemp': 4,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:40:27',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101030',
#   'sna': 'YouBike2.0_臺大永齡生醫工程館',
#   'tot': 34,
#   'sbi': 7,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:51:12',
#   'lat': 25.0136,
#   'lng': 121.54656,
#   'ar': '芳蘭路51號西北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU Yonglin Biomedical Engineering Hall',
#   'aren': 'No. 51， Fanglan Rd.(Northwest)',
#   'bemp': 27,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:51:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101031',
#   'sna': 'YouBike2.0_臺大男七舍前',
#   'tot': 20,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.01537,
#   'lng': 121.54698,
#   'ar': '長興街/長興街80巷口西側',
#   'sareaen': 'Daan Dist.',
#   'snaen': "YouBike2.0_NTU 7th Men's Dorm",
#   'aren': 'Ln. 80， Changxing St. Intersection(West)',
#   'bemp': 20,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101032',
#   'sna': 'YouBike2.0_臺大男一舍前',
#   'tot': 61,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.01637,
#   'lng': 121.54535,
#   'ar': '長興街50號西北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': "YouBike2.0_NTU 1st Men's Dorm",
#   'aren': 'No. 50， Changxing St.(Northwest)',
#   'bemp': 60,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101033',
#   'sna': 'YouBike2.0_臺大男六舍前',
#   'tot': 46,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.01664,
#   'lng': 121.5452,
#   'ar': '大安區長興街31號',
#   'sareaen': 'Daan Dist.',
#   'snaen': "YouBike2.0_NTU 6th Men's Dorm",
#   'aren': 'No. 31， Changxing St.',
#   'bemp': 45,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101034',
#   'sna': 'YouBike2.0_臺大動物醫院前',
#   'tot': 18,
#   'sbi': 7,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:42:12',
#   'lat': 25.01576,
#   'lng': 121.54291,
#   'ar': '基隆路三段155巷/基隆路四段口',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU Veterinary Hospital',
#   'aren': 'Ln. 155， Sec. 3， Keelung Rd. Intersection',
#   'bemp': 11,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:42:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101035',
#   'sna': 'YouBike2.0_臺大土木研究大樓前',
#   'tot': 11,
#   'sbi': 2,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.01787,
#   'lng': 121.5476,
#   'ar': '辛亥路三段188號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU Civil Engineering Research Building',
#   'aren': 'No. 188， Sec. 3， Xinhai Rd.',
#   'bemp': 9,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101036',
#   'sna': 'YouBike2.0_臺大萬才館前',
#   'tot': 20,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:44:11',
#   'lat': 25.02032,
#   'lng': 121.54497,
#   'ar': '臺大萬才館北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU Wan Tsai Research Hall',
#   'aren': 'NTU Wan Tsai Research Hall',
#   'bemp': 19,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:44:11',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101037',
#   'sna': 'YouBike2.0_臺大國青大樓宿舍前',
#   'tot': 20,
#   'sbi': 2,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:38:11',
#   'lat': 25.02076,
#   'lng': 121.54432,
#   'ar': '辛亥路三段30號西北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU Guo - Ching Building',
#   'aren': 'No. 30， Sec. 3， Xinhai Rd.(Northwest)',
#   'bemp': 18,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:38:11',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101038',
#   'sna': 'YouBike2.0_臺大社科院圖書館前',
#   'tot': 27,
#   'sbi': 3,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:12',
#   'lat': 25.02101,
#   'lng': 121.54284,
#   'ar': '辛亥路與復興南路口西南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU College of social Sciences Building',
#   'aren': 'Xinhai Fuxing Rd. Intersection (Southwest)',
#   'bemp': 24,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101039',
#   'sna': 'YouBike2.0_臺大法人語言訓練中心前',
#   'tot': 28,
#   'sbi': 25,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.02104,
#   'lng': 121.54081,
#   'ar': '臺大法人語言訓練中心北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU Language Training & Testing Center',
#   'aren': 'NTU Language Training & Testing Center(North)',
#   'bemp': 3,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101040',
#   'sna': 'YouBike2.0_臺大綜合體育館停車場前',
#   'tot': 25,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 13:10:51',
#   'lat': 25.0222,
#   'lng': 121.53626,
#   'ar': '臺大綜合體育館北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTU Sports Center Car Park',
#   'aren': 'NTU Sports Center(North)',
#   'bemp': 25,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 13:10:51',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101041',
#   'sna': 'YouBike2.0_辛亥新生路口東南側',
#   'tot': 21,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:37:04',
#   'lat': 25.02218,
#   'lng': 121.53474,
#   'ar': '辛亥新生路口東南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Xinhai Xinsheng Rd. Intersection (Southeast)',
#   'aren': 'Xinhai Xinsheng Rd. Intersection (Southeast)',
#   'bemp': 21,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:37:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101042',
#   'sna': 'YouBike2.0_基隆長興路口東側',
#   'tot': 15,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.01727,
#   'lng': 121.54471,
#   'ar': '基隆長興路口東側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Keelung Changxing Rd. Intersection(East)',
#   'aren': 'Keelung Changxing Rd. Intersection(East)',
#   'bemp': 14,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101091',
#   'sna': 'YouBike2.0_國北教大側門南側',
#   'tot': 25,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:28:03',
#   'lat': 25.022864,
#   'lng': 121.546622,
#   'ar': '敦南街51號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_NTUE Side Gate(South)',
#   'aren': 'No. 51， Dunnan St.',
#   'bemp': 25,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:28:03',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101092',
#   'sna': 'YouBike2.0_和平實小東北側',
#   'tot': 13,
#   'sbi': 7,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:18:14',
#   'lat': 25.021641,
#   'lng': 121.54704,
#   'ar': '敦南街73號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Heping Experiment Elementary School (Northeast)',
#   'aren': 'No. 73， Dunnan St.',
#   'bemp': 6,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:18:14',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101093',
#   'sna': 'YouBike2.0_大安區健康服務中心',
#   'tot': 15,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:28:03',
#   'lat': 25.021469,
#   'lng': 121.544069,
#   'ar': '辛亥路三段15號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Daan District Public Health Center',
#   'aren': 'No. 15， Sec. 1， Xinhai Rd.',
#   'bemp': 15,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:28:03',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101094',
#   'sna': 'YouBike2.0_辛亥泰順街口',
#   'tot': 20,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:12',
#   'lat': 25.02193,
#   'lng': 121.53165,
#   'ar': '辛亥泰順街口東南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Xinhai Taishun St. Intersection',
#   'aren': 'Xinhai Taishun St. Intersection (Southeast)',
#   'bemp': 19,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101095',
#   'sna': 'YouBike2.0_芳和國中',
#   'tot': 28,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:49:03',
#   'lat': 25.0189,
#   'lng': 121.55013,
#   'ar': '臥龍街170號(前)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Fanghe Junior High School',
#   'aren': 'No. 170， Wolong St.',
#   'bemp': 28,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:49:03',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101096',
#   'sna': 'YouBike2.0_辛亥基隆路口',
#   'tot': 20,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2021-11-01 14:46:03',
#   'lat': 25.0187,
#   'lng': 121.54757,
#   'ar': '基隆路三段/辛亥路三段(東北側)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Xinhai Keelung Rd. Intersection',
#   'aren': 'Sec. 3， Keelung Rd. & Sec. 3， Xinhai Rd. (Northeast)',
#   'bemp': 20,
#   'act': '0',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2021-11-01 14:46:03',
#   'infoDate': '2021-11-01'},
#  {'sno': '500101097',
#   'sna': 'YouBike2.0_臥龍樂業街口',
#   'tot': 19,
#   'sbi': 10,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.01856,
#   'lng': 121.55558,
#   'ar': '臥龍街234-2號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Wolong Leye St. Intersection',
#   'aren': 'No. 234-2， Wolong St.',
#   'bemp': 9,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101098',
#   'sna': 'YouBike2.0_臥龍公園',
#   'tot': 14,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 12:32:04',
#   'lat': 25.01623,
#   'lng': 121.55037,
#   'ar': '辛亥路三段223號西側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Wolong Park',
#   'aren': 'No. 223， Sec. 3， Xinhai Rd. (West)',
#   'bemp': 14,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 12:32:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101099',
#   'sna': 'YouBike2.0_嘉興公園',
#   'tot': 20,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:47:04',
#   'lat': 25.021,
#   'lng': 121.55211,
#   'ar': '樂業街101巷3號西北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Jiaxing Park',
#   'aren': 'No. 3， Ln. 101， Leye St. (Northwest)',
#   'bemp': 20,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:47:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101100',
#   'sna': 'YouBike2.0_捷運麟光站(2號出口)',
#   'tot': 25,
#   'sbi': 4,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:38:11',
#   'lat': 25.0181,
#   'lng': 121.55929,
#   'ar': '和平東路三段420號東北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Linguang Sta. (Exit 2)',
#   'aren': 'No. 420， Sec. 3， Heping E. Rd. (Northeast)',
#   'bemp': 17,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:38:11',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101101',
#   'sna': 'YouBike2.0_捷運六張犁站',
#   'tot': 18,
#   'sbi': 3,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:12',
#   'lat': 25.02397,
#   'lng': 121.55266,
#   'ar': '和平東路三段410號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Liuzhangli Sta.',
#   'aren': 'No. 410， Sec. 3， Heping E. Rd.',
#   'bemp': 15,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101102',
#   'sna': 'YouBike2.0_喬治工商',
#   'tot': 16,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:35:16',
#   'lat': 25.02705,
#   'lng': 121.55551,
#   'ar': '基隆路二段166號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_George Vocational High School of Taipei',
#   'aren': 'No. 166， Sec. 2， Keelung Rd.',
#   'bemp': 15,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:35:16',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101103',
#   'sna': 'YouBike2.0_法治公園',
#   'tot': 15,
#   'sbi': 4,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:47:12',
#   'lat': 25.02694,
#   'lng': 121.55325,
#   'ar': '通化街189號西側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Fazhi Park',
#   'aren': 'No. 189， Tonghua St. (West)',
#   'bemp': 11,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:47:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101104',
#   'sna': 'YouBike2.0_捷運臺電大樓站(2號出口)',
#   'tot': 14,
#   'sbi': 4,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:50:31',
#   'lat': 25.02021,
#   'lng': 121.52942,
#   'ar': '辛亥路一段/羅斯福路三段口北側(辛亥路側)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Taipower Building Sta. (Exit 2)',
#   'aren': 'Sec. 1， Xinhai Rd & Sec. 3， Roosevelt Rd (North)',
#   'bemp': 10,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:31',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101105',
#   'sna': 'YouBike2.0_和平金山路口',
#   'tot': 32,
#   'sbi': 4,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:12',
#   'lat': 25.02669,
#   'lng': 121.52529,
#   'ar': '和平東路一段/金山南路二段西南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 1， Heping E. Rd & Sec. 2， Jinshan S. Rd Intersection',
#   'aren': 'Sec. 1， Heping E. Rd & Sec. 2， Jinshan S. Rd Intersection (Southwest)',
#   'bemp': 28,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101107',
#   'sna': 'YouBike2.0_和平龍泉街口',
#   'tot': 17,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.0264,
#   'lng': 121.52924,
#   'ar': '和平東路一段/龍泉街口西南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 1， Heping E. Rd & Longquan St. Intersection',
#   'aren': 'Sec. 1， Heping E. Rd & Longquan St. Intersection (Southwest)',
#   'bemp': 17,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101108',
#   'sna': 'YouBike2.0_和平泰順街口',
#   'tot': 9,
#   'sbi': 5,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.02621,
#   'lng': 121.53171,
#   'ar': '和平東路一段/泰順街口東南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 1， Heping E. Rd & Taishun St  Intersection',
#   'aren': 'Sec. 1， Heping E. Rd & Taishun St  Intersection (Southeast)',
#   'bemp': 4,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101109',
#   'sna': 'YouBike2.0_臺灣師範大學(圖書館)',
#   'tot': 13,
#   'sbi': 4,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.0266,
#   'lng': 121.52973,
#   'ar': '和平東路一段129號前',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_National Taiwan Normal University (library)',
#   'aren': 'No. 129， Sec. 1， Heping E. Rd.',
#   'bemp': 9,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101110',
#   'sna': 'YouBike2.0_捷運古亭站(6號出口)',
#   'tot': 15,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:04',
#   'lat': 25.0276,
#   'lng': 121.52217,
#   'ar': '羅斯福路二段41號前',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Guting Sta. (Exit 6)',
#   'aren': 'No. 41， Sec. 2， Roosevelt Rd',
#   'bemp': 15,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101111',
#   'sna': 'YouBike2.0_捷運古亭站(5號出口)',
#   'tot': 14,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.02715,
#   'lng': 121.52293,
#   'ar': '和平東路一段19號前',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Guting Sta. (Exit 5)',
#   'aren': 'No. 19， Sec. 1， Heping E. Rd',
#   'bemp': 12,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101113',
#   'sna': 'YouBike2.0_臺北市立圖書館(總館)',
#   'tot': 19,
#   'sbi': 4,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.02895,
#   'lng': 121.5379,
#   'ar': '建國南路二段/建國南路二段151巷(橋下空間)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Taipei Public library',
#   'aren': 'Sec. 2， Jianguo S. Rd & Ln. 151， Sec. 2， Jianguo S. Rd (Under Bridge)',
#   'bemp': 15,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101114',
#   'sna': 'YouBike2.0_新生和平路口東北側',
#   'tot': 15,
#   'sbi': 3,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.02657,
#   'lng': 121.53515,
#   'ar': '新生南路二段與和平東路二段口東北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 2， Xinsheng S. Rd & Sec. 2， Heping E. Rd Intersection',
#   'aren': 'Sec. 2， Xinsheng S. Rd & Sec. 2， Heping E. Rd (Northeast)',
#   'bemp': 12,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101115',
#   'sna': 'YouBike2.0_建國和平路口西北側',
#   'tot': 20,
#   'sbi': 15,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:48:12',
#   'lat': 25.02606,
#   'lng': 121.53738,
#   'ar': '建國南路二段與和平東路二段口西北側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 2， Jianguo S. Rd & Sec. 2， Heping E. Rd Intersection',
#   'aren': 'Sec. 2， Jianguo S. Rd & Sec. 2， Heping E. Rd. (Northwest)',
#   'bemp': 4,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:48:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101116',
#   'sna': 'YouBike2.0_金華公園',
#   'tot': 11,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.02984,
#   'lng': 121.53107,
#   'ar': '金華街249號對面',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Jinhua Park',
#   'aren': 'No. 249， Jinhua St. (Opposite)',
#   'bemp': 10,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101117',
#   'sna': 'YouBike2.0_捷運東門站(3號出口)',
#   'tot': 15,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:50:23',
#   'lat': 25.03383,
#   'lng': 121.52815,
#   'ar': '信義路二段128號前',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Dongmen Sta. (Exit 3)',
#   'aren': 'No. 128， Sec. 2， Xinyi Rd.',
#   'bemp': 14,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:23',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101118',
#   'sna': 'YouBike2.0_金甌女中',
#   'tot': 12,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:40:19',
#   'lat': 25.03519,
#   'lng': 121.5245,
#   'ar': '信義路二段與杭州南路二段東南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': "YouBike2.0_Jin'ou Girls High School",
#   'aren': 'Sec. 2， Xinyi Rd. & Sec. 2， Hangzhou S. Rd. (Southeast)',
#   'bemp': 11,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:40:19',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101119',
#   'sna': 'YouBike2.0_金杭公園',
#   'tot': 20,
#   'sbi': 7,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:41:12',
#   'lat': 25.03325,
#   'lng': 121.52436,
#   'ar': '愛國東路21巷與杭州南路二段25巷口東南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Jinhang Park',
#   'aren': 'Ln. 21， Aiguo E. Rd. & Ln. 25， Sec. 2， Hangzhou S. Rd. Intersection (Southeast)',
#   'bemp': 12,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:41:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101120',
#   'sna': 'YouBike2.0_愛國金山路口',
#   'tot': 21,
#   'sbi': 8,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:50:31',
#   'lat': 25.03164,
#   'lng': 121.52661,
#   'ar': '愛國東路與杭州南路二段口西南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Aiguo & Jinshan Rd. Intersection',
#   'aren': 'Aiguo E. Rd. & Sec. 2， Hangzhou S. Rd. Intersection (Southwest)',
#   'bemp': 12,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:31',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101122',
#   'sna': 'YouBike2.0_敦化南路二段293巷口南側',
#   'tot': 14,
#   'sbi': 4,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:44:11',
#   'lat': 25.0237,
#   'lng': 121.54899,
#   'ar': '敦化南路二段293巷口南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Ln. 293， Sec. 2， Dunhua S. Rd (South)',
#   'aren': 'Ln. 293， Sec. 2， Dunhua S. Rd. (South)',
#   'bemp': 10,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:44:11',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101123',
#   'sna': 'YouBike2.0_敦化基隆路口',
#   'tot': 16,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:41:12',
#   'lat': 25.02215,
#   'lng': 121.54839,
#   'ar': '敦化南路二段218號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 2， Dunhua S. Rd & Sec. 2， Keelung Rd Intersection',
#   'aren': 'No. 218， Sec. 2， Dunhua S. Rd',
#   'bemp': 15,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:41:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101124',
#   'sna': 'YouBike2.0_安和路二段181巷口',
#   'tot': 17,
#   'sbi': 3,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.02721,
#   'lng': 121.54988,
#   'ar': '安和路二段185號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Ln. 181， Sec. 2， Anhe Rd',
#   'aren': 'No185， Sec. 2， Anhe Rd',
#   'bemp': 14,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101125',
#   'sna': 'YouBike2.0_臨江街夜市(通化街101巷口)',
#   'tot': 30,
#   'sbi': 2,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.02952,
#   'lng': 121.55406,
#   'ar': '通化街111號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Linjiang St night market (Ln. 101， Tonghua St)',
#   'aren': 'No. 101， Tonghua St.',
#   'bemp': 28,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101126',
#   'sna': 'YouBike2.0_臨江街夜市(基隆路)',
#   'tot': 17,
#   'sbi': 0,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:33:04',
#   'lat': 25.02931,
#   'lng': 121.55721,
#   'ar': '基隆路二段108號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Linjiang St night market (Keelung Rd)',
#   'aren': 'No. 108， Sec. 2， Keelung Rd.',
#   'bemp': 17,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:33:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101127',
#   'sna': 'YouBike2.0_台北科技大學億光大樓',
#   'tot': 46,
#   'sbi': 10,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:51:12',
#   'lat': 25.04177,
#   'lng': 121.53833,
#   'ar': '忠孝東路三段81號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_National Taipei University of Technology (Everlight Building)',
#   'aren': 'No. 81， Sec. 3， Zhongxiao E. Rd.',
#   'bemp': 33,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:51:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101128',
#   'sna': 'YouBike2.0_新生南路一段119巷口',
#   'tot': 33,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.04003,
#   'lng': 121.53299,
#   'ar': '新生南路一段113號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Ln. 119， Sec. 1， Xinsheng S. Rd Intersection',
#   'aren': 'No. 113， Ln. 119， Sec. 1， Xinsheng S. Rd.',
#   'bemp': 32,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101129',
#   'sna': 'YouBike2.0_幸安國小(仁愛路)',
#   'tot': 16,
#   'sbi': 5,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:35:24',
#   'lat': 25.03753,
#   'lng': 121.53523,
#   'ar': '仁愛路三段22號',
#   'sareaen': 'Daan Dist.',
#   'snaen': "YouBike2.0_Xing'an Elementary School (Ren'ai Rd)",
#   'aren': "No. 22， Sec. 3， Ren'ai Rd.",
#   'bemp': 11,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:35:24',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101130',
#   'sna': 'YouBike2.0_民榮公園',
#   'tot': 15,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:40:19',
#   'lat': 25.03534,
#   'lng': 121.5354,
#   'ar': '建國南路一段304巷45號南側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Minrong Park',
#   'aren': 'No. 45， Ln. 304， Sec. 1， Jianguo S. Rd. (South)',
#   'bemp': 14,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:40:19',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101131',
#   'sna': 'YouBike2.0_復興南路1段340巷口',
#   'tot': 18,
#   'sbi': 11,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:12',
#   'lat': 25.03701,
#   'lng': 121.54348,
#   'ar': '復興南路一段信義路三段147巷45弄口',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Ln. 340， Sec. 1， Fuxing S. Rd Intersection',
#   'aren': 'Sec. 1， Fuxing S. Rd & Aly. 45， Ln. 147， Sec. 3， Xinyi Rd Intersection.',
#   'bemp': 7,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101132',
#   'sna': 'YouBike2.0_建國濟南路口',
#   'tot': 18,
#   'sbi': 3,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.03935,
#   'lng': 121.53828,
#   'ar': '建國南路一段/濟南路三段口(東南側)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 1， Jianguo S. Rd & Sec. 3， Jinan Rd Intersection',
#   'aren': 'Sec. 1， Jianguo S. Rd & Sec. 3， Jinan Rd Intersection. (Southeast)',
#   'bemp': 13,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101133',
#   'sna': 'YouBike2.0_捷運忠孝復興站(2號出口)',
#   'tot': 23,
#   'sbi': 17,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:12',
#   'lat': 25.04035,
#   'lng': 121.5436,
#   'ar': '復興南路一段/仁愛路三段123巷13弄(西北側)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Zhongxiao Fuxing Sta (Exit 2)',
#   'aren': "Sec. 1， Fuxing S. R & Aly. 13， Ln. 123， Sec. 3， Ren'ai Rd. (Northwest)",
#   'bemp': 5,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101134',
#   'sna': 'YouBike2.0_捷運大安站(4號出口)',
#   'tot': 13,
#   'sbi': 6,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.0332,
#   'lng': 121.5439,
#   'ar': '信義路4段6號(前)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Da’an Sta (Exit 4)',
#   'aren': 'No. 6， Sec. 4， Xinyi Rd.',
#   'bemp': 6,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101135',
#   'sna': 'YouBike2.0_捷運大安站(2號出口)',
#   'tot': 22,
#   'sbi': 8,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:12',
#   'lat': 25.03358,
#   'lng': 121.54141,
#   'ar': '信義路3段143號(前)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Da’an Sta (Exit 2)',
#   'aren': 'No. 143， Sec. 3， Xinyi Rd.',
#   'bemp': 14,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101136',
#   'sna': 'YouBike2.0_信義大安路口(信維大樓)',
#   'tot': 12,
#   'sbi': 5,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:50:31',
#   'lat': 25.03317,
#   'lng': 121.54639,
#   'ar': '信義路四段74號(前)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 4， Xinyi Rd & Da’an Rd Intersection (Xinwei Building)',
#   'aren': 'No. 74， Sec. 4， Xinyi Rd.',
#   'bemp': 6,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:31',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101137',
#   'sna': 'YouBike2.0_龍門廣場',
#   'tot': 19,
#   'sbi': 3,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:47:12',
#   'lat': 25.04092,
#   'lng': 121.54825,
#   'ar': '敦化南路一段與敦化南路一段236巷口',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Long Men Plaza',
#   'aren': 'Sec. 1， Dunhua S. Rd & Ln. 236， Sec. 1， Dunhua S. Rd Intersection.',
#   'bemp': 16,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:47:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101138',
#   'sna': 'YouBike2.0_仁愛安和路口',
#   'tot': 8,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.03754,
#   'lng': 121.55285,
#   'ar': '仁愛路四段258號前',
#   'sareaen': 'Daan Dist.',
#   'snaen': "YouBike2.0_Sec. 4， Ren'ai Rd & Sec. 1， Anhe Rd Intersection",
#   'aren': "No. 74， Sec. 4， Ren'ai Rd.",
#   'bemp': 5,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101139',
#   'sna': 'YouBike2.0_信義敦化路口',
#   'tot': 19,
#   'sbi': 4,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:54:12',
#   'lat': 25.03333,
#   'lng': 121.54977,
#   'ar': '信義路四段155號前',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 4， Xinyi Rd & Sec. 1， Dunhua S. Rd Intersection',
#   'aren': 'No. 155， Sec. 4， Xinyi Rd',
#   'bemp': 15,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101140',
#   'sna': 'YouBike2.0_仁愛國中',
#   'tot': 25,
#   'sbi': 12,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:46:13',
#   'lat': 25.03706,
#   'lng': 121.55166,
#   'ar': '安和路一段75號(對面)',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Ren Ai Junior High School',
#   'aren': 'No. 75， Sec. 1， Anhe Rd.',
#   'bemp': 12,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:46:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101141',
#   'sna': 'YouBike2.0_捷運信義安和站(2號出口)',
#   'tot': 26,
#   'sbi': 7,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:12',
#   'lat': 25.03304,
#   'lng': 121.55171,
#   'ar': '信義路四段188號前',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Xinyi Anhe Sta (Exit 2)',
#   'aren': 'No. 188， Sec. 4， Xinyi Rd',
#   'bemp': 18,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101142',
#   'sna': 'YouBike2.0_八德市場',
#   'tot': 30,
#   'sbi': 1,
#   'sarea': '大安區',
#   'mday': '2022-02-11 13:48:14',
#   'lat': 25.04463,
#   'lng': 121.53665,
#   'ar': '市民大道三段170號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Bade Traditional Market',
#   'aren': 'No. 170， Sec. 3， Civic Blvd.',
#   'bemp': 29,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 13:48:14',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101143',
#   'sna': 'YouBike2.0_昌隆公園',
#   'tot': 16,
#   'sbi': 5,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:52:12',
#   'lat': 25.04448,
#   'lng': 121.53946,
#   'ar': '市民大道三段206號西側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Changlong Park',
#   'aren': 'No. 206， Sec. 3， Civic Blvd. (West)',
#   'bemp': 11,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101144',
#   'sna': 'YouBike2.0_捷運大安森林公園站(2號出口)',
#   'tot': 22,
#   'sbi': 8,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.03332,
#   'lng': 121.53435,
#   'ar': '捷運大安森林公園站(2號出口)西側',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_MRT Daan Park Sta. (Exit 2)',
#   'aren': 'MRT Daan Park Sta. (Exit 2) (West)',
#   'bemp': 14,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101145',
#   'sna': 'YouBike2.0_信義延吉街口',
#   'tot': 15,
#   'sbi': 2,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:45:29',
#   'lat': 25.03318,
#   'lng': 121.55725,
#   'ar': '信義路四段353號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Sec. 4，Xinyi Rd & Yanji St Intersection',
#   'aren': 'No. 353， Sec. 4， Xinyi Rd.',
#   'bemp': 13,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:45:29',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101146',
#   'sna': 'YouBike2.0_光信公園(光復南路456巷)',
#   'tot': 15,
#   'sbi': 3,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:43:12',
#   'lat': 25.03513,
#   'lng': 121.5561,
#   'ar': '延吉街249號',
#   'sareaen': 'Daan Dist.',
#   'snaen': 'YouBike2.0_Guangxin Park (Ln. 456， Guangfu S. Rd)',
#   'aren': 'No. 249， Yanji St.',
#   'bemp': 12,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:43:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500101147',
#   'sna': 'YouBike2.0_僑安地下停車場(2號出口)東南側',
#   'tot': 20,
#   'sbi': 9,
#   'sarea': '大安區',
#   'mday': '2022-02-11 14:46:13',
#   'lat': 25.0391,
#   'lng': 121.5569,
#   'ar': '光復南路290巷5號',
# ...
#   'tot': 20,
#   'sbi': 0,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:14:04',
#   'lat': 25.01595,
#   'lng': 121.53791,
#   'ar': '臺大共同教學館東北側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Common Subjects Classroom Building(North)',
#   'aren': 'NTU Common Subjects Classroom Building(Northeast)',
#   'bemp': 20,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:14:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119060',
#   'sna': 'YouBike2.0_臺大共同教室東南側',
#   'tot': 12,
#   'sbi': 0,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:50:23',
#   'lat': 25.01566,
#   'lng': 121.53786,
#   'ar': '臺大共同教學館東南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Common Subjects Classroom Building(Southeast)',
#   'aren': 'NTU Common Subjects Classroom Building(Southeast)',
#   'bemp': 12,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:23',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119061',
#   'sna': 'YouBike2.0_臺大鹿鳴堂東側',
#   'tot': 27,
#   'sbi': 7,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:44:12',
#   'lat': 25.01511,
#   'lng': 121.53786,
#   'ar': '臺大鹿鳴廣場人行道側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU LuMing Hall(East)',
#   'aren': 'NTU Lu Ming Square(Sidewalk)',
#   'bemp': 20,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:44:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119062',
#   'sna': 'YouBike2.0_臺大公館停車場西北側',
#   'tot': 12,
#   'sbi': 5,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:50:32',
#   'lat': 25.01345,
#   'lng': 121.53798,
#   'ar': '臺大公館停車場西北側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Gongguan Car Park (Northwest)',
#   'aren': 'NTU Gongguan Car Park (Northwest)',
#   'bemp': 7,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:32',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119063',
#   'sna': 'YouBike2.0_臺大第二行政大樓南側',
#   'tot': 10,
#   'sbi': 0,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:53:04',
#   'lat': 25.01603,
#   'lng': 121.53635,
#   'ar': '臺大行政大樓西側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU 2nd Administration Building(South)',
#   'aren': 'NTU Administration Building(West)',
#   'bemp': 10,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119064',
#   'sna': 'YouBike2.0_臺大明達館機車停車場',
#   'tot': 10,
#   'sbi': 4,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:52:13',
#   'lat': 25.01754,
#   'lng': 121.54398,
#   'ar': '臺大明達館西側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Ming - Da Hall Parking',
#   'aren': 'NTU Ming - Da Hall(West)',
#   'bemp': 6,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119065',
#   'sna': 'YouBike2.0_臺大二號館',
#   'tot': 10,
#   'sbi': 2,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:41:13',
#   'lat': 25.01699,
#   'lng': 121.53574,
#   'ar': '臺大物理文物廳北側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Building No.2',
#   'aren': 'NTU Heritage Hall of Physics',
#   'bemp': 8,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:41:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119066',
#   'sna': 'YouBike2.0_臺大凝態館南側',
#   'tot': 20,
#   'sbi': 8,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:50:32',
#   'lat': 25.02157,
#   'lng': 121.53633,
#   'ar': '臺大物理系館南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Center for Condensed Matter Sciences(South)',
#   'aren': 'NTU Dept. of Physics Library',
#   'bemp': 12,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:32',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119067',
#   'sna': 'YouBike2.0_臺大社科院西側',
#   'tot': 42,
#   'sbi': 15,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:50:32',
#   'lat': 25.02053,
#   'lng': 121.54145,
#   'ar': '臺大社科院西側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU College of social Sciences Building(West)',
#   'aren': 'NTU College of social Sciences Building(West)',
#   'bemp': 21,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:32',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119068',
#   'sna': 'YouBike2.0_臺大社會系館南側',
#   'tot': 25,
#   'sbi': 16,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:52:13',
#   'lat': 25.01987,
#   'lng': 121.54175,
#   'ar': '臺大社會及社工館南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Department of Sociology(South)',
#   'aren': 'NTU Dept. of Sociology / Dept. of Social Work(South)',
#   'bemp': 5,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119069',
#   'sna': 'YouBike2.0_臺大思亮館東南側',
#   'tot': 10,
#   'sbi': 4,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:03:16',
#   'lat': 25.02074,
#   'lng': 121.53906,
#   'ar': '臺大思亮館東南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Shih - Liang Hall(Southeast)',
#   'aren': 'NTU Shih - Liang Hall(Southeast)',
#   'bemp': 6,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:03:16',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119070',
#   'sna': 'YouBike2.0_臺大椰林小舖',
#   'tot': 25,
#   'sbi': 0,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:54:03',
#   'lat': 25.01561,
#   'lng': 121.53583,
#   'ar': '臺大椰林小舖旁',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Green Cabin',
#   'aren': 'NTU Green Cabin',
#   'bemp': 25,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:03',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119071',
#   'sna': 'YouBike2.0_臺大計資中心南側',
#   'tot': 19,
#   'sbi': 7,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.02036,
#   'lng': 121.53992,
#   'ar': '臺大計算機網路資訊中心南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Computer and Information Networking Center(South)',
#   'aren': 'NTU Computer and Information Networking Center(South)',
#   'bemp': 7,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119072',
#   'sna': 'YouBike2.0_臺大原分所北側',
#   'tot': 12,
#   'sbi': 10,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:25:28',
#   'lat': 25.01881,
#   'lng': 121.53868,
#   'ar': '臺大原子與分子科學研究所東北側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Institute of Atomic and Molecular Sciences(North)',
#   'aren': 'NTU Institute of Atomic and Molecular Sciences(Northeast)',
#   'bemp': 2,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:25:28',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119073',
#   'sna': 'YouBike2.0_臺大校史館南側',
#   'tot': 10,
#   'sbi': 0,
#   'sarea': '臺大專區',
#   'mday': '2021-11-30 15:46:12',
#   'lat': 25.01751,
#   'lng': 121.53569,
#   'ar': '臺大校史館南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Library/Gallery of University History(South)',
#   'aren': 'NTU Library/Gallery of University History(South)',
#   'bemp': 10,
#   'act': '0',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2021-11-30 15:46:12',
#   'infoDate': '2021-11-30'},
#  {'sno': '500119074',
#   'sna': 'YouBike2.0_臺大生命科學館西北側',
#   'tot': 10,
#   'sbi': 6,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:44:12',
#   'lat': 25.01548,
#   'lng': 121.53825,
#   'ar': '臺大動物博物館西側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Life Science Building(Northwest)',
#   'aren': 'Museum of Zoology(West)',
#   'bemp': 4,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:44:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119075',
#   'sna': 'YouBike2.0_臺大第一活動中心西南側',
#   'tot': 40,
#   'sbi': 5,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:52:13',
#   'lat': 25.01761,
#   'lng': 121.53995,
#   'ar': '第一學生活動中心東南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU 1st Student Activity Center(Southwest)',
#   'aren': 'NTU 1st Student Activity Center(Southeast)',
#   'bemp': 35,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:52:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119076',
#   'sna': 'YouBike2.0_臺大博理館西側',
#   'tot': 22,
#   'sbi': 12,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:54:13',
#   'lat': 25.01922,
#   'lng': 121.54195,
#   'ar': '臺大博理館西側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Barry Lam Hall(West)',
#   'aren': 'NTU Barry Lam Hall(West)',
#   'bemp': 2,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119077',
#   'sna': 'YouBike2.0_臺大博雅館西側',
#   'tot': 56,
#   'sbi': 1,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:11:09',
#   'lat': 25.0189,
#   'lng': 121.536,
#   'ar': '臺大博雅館西側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Liberal Education Classroom Building(West)',
#   'aren': 'NTU Liberal Education Classroom Building(West)',
#   'bemp': 55,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:11:09',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119078',
#   'sna': 'YouBike2.0_臺大森林館北側',
#   'tot': 10,
#   'sbi': 3,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:51:12',
#   'lat': 25.01704,
#   'lng': 121.53888,
#   'ar': '臺大森林系學系北側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Forestry Building(North)',
#   'aren': 'NTU Forestry Building(North)',
#   'bemp': 7,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:51:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119079',
#   'sna': 'YouBike2.0_臺大一號館',
#   'tot': 19,
#   'sbi': 1,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.01698,
#   'lng': 121.53455,
#   'ar': '臺大植物魚類標本館一號館北側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Building No.1',
#   'aren': 'NTU Building No.1(North)',
#   'bemp': 18,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119080',
#   'sna': 'YouBike2.0_臺大小小福西南側',
#   'tot': 10,
#   'sbi': 0,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:54:13',
#   'lat': 25.01539,
#   'lng': 121.53686,
#   'ar': '臺大進修教育大樓',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Xiao Xiao Fu Commissary(Southwest)',
#   'aren': 'NTU Omnium Gatherum Building',
#   'bemp': 10,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119081',
#   'sna': 'YouBike2.0_臺大教研館北側',
#   'tot': 11,
#   'sbi': 10,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:50:23',
#   'lat': 25.01337,
#   'lng': 121.53909,
#   'ar': '臺大雅頌廣場東南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Teaching and Research Building(North)',
#   'aren': 'NTU The Odeum Square(Southeast)',
#   'bemp': 1,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:23',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119082',
#   'sna': 'YouBike2.0_臺大四號館東北側',
#   'tot': 10,
#   'sbi': 0,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 12:18:04',
#   'lat': 25.01703,
#   'lng': 121.53781,
#   'ar': '臺大園藝暨景觀學系北側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Building No.4(Northeast)',
#   'aren': 'NTU Department of Horticulture(North)',
#   'bemp': 10,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 12:18:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119083',
#   'sna': 'YouBike2.0_臺大新生教室南側',
#   'tot': 18,
#   'sbi': 14,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:50:32',
#   'lat': 25.0196,
#   'lng': 121.53846,
#   'ar': '臺大新生教學館南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Freshman Classroom Building(South)',
#   'aren': 'NTU Freshman Classroom Building(South)',
#   'bemp': 2,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:50:32',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119084',
#   'sna': 'YouBike2.0_臺大鄭江樓北側',
#   'tot': 10,
#   'sbi': 5,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:54:13',
#   'lat': 25.019,
#   'lng': 121.54305,
#   'ar': '臺大新聞研究所南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Tseng Jiang Hall(North)',
#   'aren': 'NTU Graduate Institute of Journalism(South)',
#   'bemp': 5,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119085',
#   'sna': 'YouBike2.0_臺大電機二館東南側',
#   'tot': 14,
#   'sbi': 6,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:32:12',
#   'lat': 25.01857,
#   'lng': 121.54247,
#   'ar': '臺大電機二館南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU E. E. Building No. 2(Southeast)',
#   'aren': 'NTU E. E. Building No. 2(Southeast)',
#   'bemp': 2,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:32:12',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119086',
#   'sna': 'YouBike2.0_臺大圖資系館北側',
#   'tot': 10,
#   'sbi': 10,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:21:04',
#   'lat': 25.01804,
#   'lng': 121.53928,
#   'ar': '臺大圖書資訊館北側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Dept. of Library and Information Sciences(North)',
#   'aren': 'NTU Dept. of Library and Information Sciences(North)',
#   'bemp': 0,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:21:04',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119087',
#   'sna': 'YouBike2.0_臺大總圖書館西南側',
#   'tot': 30,
#   'sbi': 6,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:54:13',
#   'lat': 25.0169,
#   'lng': 121.54031,
#   'ar': '臺大圖書館西南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Main Library(Southwest)',
#   'aren': 'NTU Main Library(Southwest)',
#   'bemp': 24,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119088',
#   'sna': 'YouBike2.0_臺大黑森林西側',
#   'tot': 20,
#   'sbi': 5,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:54:13',
#   'lat': 25.01995,
#   'lng': 121.54347,
#   'ar': '臺大霖澤館南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Black Forest(West)',
#   'aren': 'NTU Tsai Lecture Hall(South)',
#   'bemp': 15,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:54:13',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119089',
#   'sna': 'YouBike2.0_臺大獸醫館南側',
#   'tot': 10,
#   'sbi': 6,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:45:30',
#   'lat': 25.01791,
#   'lng': 121.54242,
#   'ar': '臺大獸醫系館南側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Dept. of Veterinary Medicine(South)',
#   'aren': 'NTU Dept. of Veterinary Medicine(South)',
#   'bemp': 4,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:45:30',
#   'infoDate': '2022-02-11'},
#  {'sno': '500119090',
#   'sna': 'YouBike2.0_臺大新體育館東南側',
#   'tot': 40,
#   'sbi': 15,
#   'sarea': '臺大專區',
#   'mday': '2022-02-11 14:53:12',
#   'lat': 25.02112,
#   'lng': 121.53591,
#   'ar': '臺大體育館東側',
#   'sareaen': 'NTU Dist',
#   'snaen': 'YouBike2.0_NTU Sports Center(Southeast)',
#   'aren': 'NTU Sports Center(East)',
#   'bemp': 25,
#   'act': '1',
#   'srcUpdateTime': '2022-02-11 14:55:12',
#   'updateTime': '2022-02-11 14:55:22',
#   'infoTime': '2022-02-11 14:53:12',
#   'infoDate': '2022-02-11'}]
